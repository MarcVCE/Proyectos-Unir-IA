# %% [markdown]
# # 🤖 Chatbot con Fallback Automático (OpenAI → Anthropic → Google)
#
# **Reto proyecto — Desarrollo de Soluciones IA**
#
# Chatbot en Python con un sistema de *fallback* en cascada entre tres proveedores de IA. Por defecto usa **Azure OpenAI**; si falla pasa a **Anthropic Claude**; si este también falla pasa a **Google Gemini**; y si ninguno responde, devuelve una **respuesta preconfigurada**. El historial completo de la conversación se mantiene **en memoria** y se conserva entre cambios de proveedor.
#
# ### Mapeo de la estructura de archivos pedida → celdas de este notebook
#
# ```
# ├── main.py                      → Celda «CLI» (run_cli)
# ├── providers/
# │   ├── __init__.py              → (implícito)
# │   ├── openai_provider.py       → Celda «Proveedor Azure OpenAI»
# │   ├── anthropic_provider.py    → Celda «Proveedor Anthropic»
# │   └── gemini_provider.py       → Celda «Proveedor Google Gemini»
# ├── core/
# │   ├── __init__.py              → (implícito)
# │   ├── chatbot.py               → Celda «Lógica del chatbot + fallback»
# │   └── conversation.py          → Celda «Gestión del historial»
# ├── requirements.txt             → Celda de dependencias
# ├── .env                         → Celda de configuración
# └── README.md                    → Este encabezado
# ```
#
# > **Nota sobre las API KEY:** no es necesario incluir las claves al entregar la solución. > Se cargan desde un archivo `.env` local mediante `python-dotenv`.

# %% [markdown]
# ## 1. Dependencias (`requirements.txt`)
#
# ```text
# openai
# anthropic
# google-genai
# python-dotenv
# ```
#
# Ejecuta la siguiente celda una sola vez para instalarlas.

# %%
# Instalación de los SDK oficiales (ejecutar una vez)
# %pip install -q openai anthropic google-genai python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Configuración (`.env`)
#
# Crea un archivo `.env` en la misma carpeta que este notebook con tus claves. **No subas este archivo** a tu entrega; mantenlo en tu entorno local.
#
# ```dotenv
# # --- OpenAI vía Azure OpenAI (credenciales del lab) ---
# # Endpoint COMPATIBLE con OpenAI (acaba en /openai/v1/)
# AZURE_OPENAI_ENDPOINT=https://marcosventosa0554426-resource.cognitiveservices.azure.com/openai/v1/
# AZURE_OPENAI_API_KEY=tu_clave_de_azure_openai
# # Elige el cliente: openai (Opción 2, por defecto) | azure (Opción 1)
# AZURE_OPENAI_CLIENT=openai
# # Solo necesaria para la Opción 1 (cliente AzureOpenAI):
# AZURE_OPENAI_API_VERSION=2024-12-01-preview
# # En Azure, 'model' es el NOMBRE DEL DEPLOYMENT. Modelos del lab disponibles:
# # gpt-4o | gpt-4o-mini | gpt-5.2-chat | gpt-5.4-mini
# OPENAI_MODEL=gpt-4o-mini
#
# # --- Anthropic Claude (clave directa de console.anthropic.com) ---
# ANTHROPIC_API_KEY=sk-ant-...
# ANTHROPIC_MODEL=claude-haiku-4-5-20251001
# # (Opcional) Claude vía Azure AI Foundry: endpoint del deployment.
# # Si lo dejas vacío, se usa la clave directa de Anthropic de arriba.
# # ANTHROPIC_BASE_URL=https://<tu-recurso>.services.ai.azure.com/...
#
# # --- Google Gemini (clave de Google AI Studio: aistudio.google.com) ---
# GEMINI_API_KEY=AIza...
# GEMINI_MODEL=gemini-2.5-flash
#
# SYSTEM_PROMPT=Eres un asistente útil y conciso. Respondes en español.
# FALLBACK_MESSAGE=Lo siento, ahora mismo no puedo procesar tu mensaje. Intenta de nuevo más tarde.
# ```
#
# > **OpenAI ahora es Azure OpenAI:** se usa el cliente `OpenAI` apuntando a `base_url=AZURE_OPENAI_ENDPOINT` (endpoint compatible con OpenAI del lab). El campo `model` debe ser el **nombre del *deployment*** en Azure, no el nombre genérico del modelo.
#
# La siguiente celda carga esas variables de entorno.

# %%
import os
from dotenv import load_dotenv

# Carga las variables de entorno definidas en .env
load_dotenv()

# Comprobación informativa (no muestra las claves)
for var in ("AZURE_OPENAI_ENDPOINT", "AZURE_OPENAI_API_KEY",
            "ANTHROPIC_API_KEY", "GEMINI_API_KEY"):
    estado = "✅ configurada" if os.getenv(var) else "❌ no encontrada"
    print(f"{var}: {estado}")
# Out:
# AZURE_OPENAI_ENDPOINT: ✅ configurada
# AZURE_OPENAI_API_KEY: ✅ configurada
# ANTHROPIC_API_KEY: ✅ configurada
# GEMINI_API_KEY: ✅ configurada

# %% [markdown]
# ## 3. Gestión del historial (`core/conversation.py`)
#
# Clase `Conversation` que guarda el historial completo usuario↔asistente **en memoria** (sin base de datos externa). Mantiene un formato canónico de mensajes `{"role": "user"|"assistant", "content": str}` que cada proveedor traduce a su propio formato. El *system prompt* se almacena por separado porque cada SDK lo trata de forma distinta.

# %%
class Conversation:
    """Mantiene el historial de la conversación en memoria."""

    def __init__(self, system_prompt: str | None = None):
        self.system_prompt = system_prompt
        self._messages: list[dict] = []

    def add_user_message(self, content: str) -> None:
        self._messages.append({"role": "user", "content": content})

    def add_assistant_message(self, content: str) -> None:
        self._messages.append({"role": "assistant", "content": content})

    @property
    def messages(self) -> list[dict]:
        """Copia del historial en formato canónico (user/assistant)."""
        return list(self._messages)

    def clear(self) -> None:
        self._messages.clear()

    def __len__(self) -> int:
        return len(self._messages)

    def __repr__(self) -> str:
        return f"Conversation({len(self._messages)} mensajes)"

# %% [markdown]
# ## 4. Interfaz común de proveedores
#
# Todos los proveedores comparten la misma interfaz: un método `generate(conversation)` que **transmite la respuesta en streaming** por pantalla y devuelve el texto completo, o lanza una excepción si falla. Esto permite que la lógica de fallback los trate de forma intercambiable.
#
# Los clientes de cada SDK se crean de forma **perezosa** (*lazy*): así, si falta una API KEY, el proveedor simplemente falla al generar y se activa el fallback, en lugar de romper el notebook al definir las clases.

# %%
class BaseProvider:
    """Interfaz común a todos los proveedores."""
    name: str = "base"

    def generate(self, conversation: "Conversation") -> str:
        raise NotImplementedError

# %% [markdown]
# ## 5. Proveedor OpenAI vía Azure (`providers/openai_provider.py`)
#
# Soporta **las dos formas de conexión** del lab, elegidas con la variable `AZURE_OPENAI_CLIENT` del `.env`:
#
# * **`openai` (Opción 2, por defecto):** cliente `OpenAI` apuntando a `base_url=.../openai/v1/` (endpoint compatible con OpenAI). Cambio mínimo respecto a OpenAI estándar.
# * **`azure` (Opción 1):** cliente `AzureOpenAI` con `api_version` + `azure_endpoint` (el dialecto nativo de Azure).
#
# Notas comunes a ambas:
# * **`model` = nombre del *deployment*** en Azure (p. ej. `gpt-4o-mini`), no el nombre genérico del modelo.
# * **API Responses** (`client.responses.create`) en **streaming**: los dos clientes la soportan. Se procesan los eventos `response.output_text.delta`.
# * El proveedor **normaliza el endpoint** automáticamente: da igual si en `.env` pones la URL base del recurso o la que acaba en `/openai/v1/`; ajusta lo necesario según el modo.
# * Si algún *deployment* no soportara Responses, cambia a `client.chat.completions.create(...)`.

# %%
class AzureOpenAIProvider(BaseProvider):
    name = "Azure OpenAI"

    def __init__(self, model: str = "gpt-4o-mini", client_mode: str | None = None,
                 api_key: str | None = None, endpoint: str | None = None,
                 api_version: str | None = None):
        # En Azure, 'model' es el NOMBRE DEL DEPLOYMENT
        self.model = model
        # client_mode: "openai" (Opción 2) | "azure" (Opción 1)
        self._client_mode = client_mode
        self._api_key = api_key
        self._endpoint = endpoint
        self._api_version = api_version
        self._client = None

    @property
    def client(self):
        if self._client is None:
            mode = (self._client_mode
                    or os.getenv("AZURE_OPENAI_CLIENT", "openai")).lower()
            api_key = self._api_key or os.getenv("AZURE_OPENAI_API_KEY")
            endpoint = self._endpoint or os.getenv("AZURE_OPENAI_ENDPOINT", "")

            if mode == "azure":
                # --- Opción 1: cliente AzureOpenAI (dialecto nativo de Azure) ---
                from openai import AzureOpenAI
                # azure_endpoint = URL base del recurso (SIN /openai/v1/)
                base = endpoint.split("/openai/")[0].rstrip("/") + "/"
                self._client = AzureOpenAI(
                    api_version=self._api_version
                        or os.getenv("AZURE_OPENAI_API_VERSION", "2024-12-01-preview"),
                    azure_endpoint=base,
                    api_key=api_key,
                    timeout=30.0,      # falla rápido si no responde
                    max_retries=1,
                )
            else:
                # --- Opción 2: cliente OpenAI con base_url (compatible OpenAI) ---
                from openai import OpenAI
                # base_url debe acabar en /openai/v1/
                base_url = endpoint
                if "/openai/v1" not in base_url:
                    base_url = base_url.rstrip("/") + "/openai/v1/"
                self._client = OpenAI(
                    base_url=base_url,
                    api_key=api_key,
                    timeout=30.0,
                    max_retries=1,
                )
        return self._client

    def generate(self, conversation: "Conversation") -> str:
        kwargs = {
            "model": self.model,               # nombre del deployment en Azure
            "input": conversation.messages,    # historial role/content
            "stream": True,                    # modo streaming
        }
        if conversation.system_prompt:
            kwargs["instructions"] = conversation.system_prompt

        # API Responses en streaming (válida para ambos clientes)
        stream = self.client.responses.create(**kwargs)

        partes: list[str] = []
        for event in stream:
            if event.type == "response.output_text.delta":
                print(event.delta, end="", flush=True)
                partes.append(event.delta)
        print()
        return "".join(partes)

# %% [markdown]
# ## 6. Proveedor Anthropic (`providers/anthropic_provider.py`)
#
# * Cliente `anthropic.Anthropic` del SDK oficial.
# * Modelo configurable (por defecto `claude-haiku-4-5-20251001`).
# * **Streaming** con `client.messages.stream(...)` e iterando sobre `stream.text_stream`.
# * En Anthropic el *system prompt* va en el parámetro `system` (fuera de `messages`) y `max_tokens` es obligatorio. El historial `user/assistant` es directamente compatible.
# * **Dos vías de credenciales**, según el `.env`:
#   * **Anthropic directo** (por defecto): solo `ANTHROPIC_API_KEY` de `console.anthropic.com`.
#   * **Claude en Azure AI Foundry**: rellena además `ANTHROPIC_BASE_URL` con el *endpoint* del deployment. El `model` debe ser el **nombre del deployment** en Foundry. Si `ANTHROPIC_BASE_URL` está vacío, usa la vía directa.

# %%
class AnthropicProvider(BaseProvider):
    name = "Anthropic"

    def __init__(self, model: str = "claude-haiku-4-5-20251001",
                 api_key: str | None = None, base_url: str | None = None,
                 max_tokens: int = 1024):
        self.model = model
        self.max_tokens = max_tokens
        self._api_key = api_key
        self._base_url = base_url
        self._client = None

    @property
    def client(self):
        if self._client is None:
            import anthropic
            # base_url solo se usa si apuntamos a Claude en Azure AI Foundry.
            # Si ANTHROPIC_BASE_URL está vacío, queda None -> Anthropic directo.
            base_url = self._base_url or os.getenv("ANTHROPIC_BASE_URL") or None
            self._client = anthropic.Anthropic(
                api_key=self._api_key or os.getenv("ANTHROPIC_API_KEY"),
                base_url=base_url,
                timeout=30.0,      # falla rápido si no responde
                max_retries=1,
            )
        return self._client

    def generate(self, conversation: "Conversation") -> str:
        kwargs = {
            "model": self.model,                 # en Foundry: nombre del deployment
            "max_tokens": self.max_tokens,
            "messages": conversation.messages,   # user/assistant compatible
        }
        if conversation.system_prompt:
            kwargs["system"] = conversation.system_prompt

        partes: list[str] = []
        # Streaming: text_stream entrega el texto por fragmentos a medida que llega
        with self.client.messages.stream(**kwargs) as stream:
            for texto in stream.text_stream:
                print(texto, end="", flush=True)
                partes.append(texto)
        print()
        return "".join(partes)

# %% [markdown]
# ## 7. Proveedor Google Gemini (`providers/gemini_provider.py`)
#
# * SDK `google-genai` (`from google import genai`).
# * Modelo configurable (por defecto `gemini-2.5-flash`).
# * **Streaming** con `client.models.generate_content_stream(...)`.
# * Google usa otro formato: roles `user`/`model` (el asistente es `model`) y `parts`. El *system prompt* se pasa en `GenerateContentConfig(system_instruction=...)`. Se incluye un conversor del formato canónico al de Gemini.

# %%
class GeminiProvider(BaseProvider):
    name = "Google Gemini"

    def __init__(self, model: str = "gemini-2.5-flash", api_key: str | None = None):
        self.model = model
        self._api_key = api_key
        self._client = None

    @property
    def client(self):
        if self._client is None:
            from google import genai
            from google.genai import types
            self._client = genai.Client(
                api_key=self._api_key or os.getenv("GEMINI_API_KEY"),
                http_options=types.HttpOptions(timeout=30_000),  # 30 s (en ms)
            )
        return self._client

    @staticmethod
    def _to_contents(conversation: Conversation) -> list[dict]:
        """Convierte el historial canónico al formato de Gemini (user/model + parts)."""
        contents = []
        for m in conversation.messages:
            role = "model" if m["role"] == "assistant" else "user"
            contents.append({"role": role, "parts": [{"text": m["content"]}]})
        return contents

    def generate(self, conversation: Conversation) -> str:
        from google.genai import types

        config = None
        if conversation.system_prompt:
            config = types.GenerateContentConfig(
                system_instruction=conversation.system_prompt
            )

        stream = self.client.models.generate_content_stream(  # modo streaming
            model=self.model,
            contents=self._to_contents(conversation),
            config=config,
        )

        partes: list[str] = []
        for chunk in stream:
            if chunk.text:
                print(chunk.text, end="", flush=True)
                partes.append(chunk.text)
        print()
        return "".join(partes)

# %% [markdown]
# ## 8. Lógica del chatbot y fallback (`core/chatbot.py`)
#
# La clase `Chatbot` recibe la lista ordenada de proveedores y orquesta la **cascada**:
#
# 1. Añade el mensaje del usuario al historial.
# 2. Intenta cada proveedor **en orden de prioridad** (OpenAI → Anthropic → Google).
# 3. Captura cualquier excepción (errores de conectividad, límites de API, claves ausentes, respuestas vacías…), **notifica el cambio de proveedor** y pasa al siguiente.
# 4. Si los tres fallan, responde con un **mensaje preconfigurado**.
# 5. En todos los casos guarda la respuesta del asistente para **mantener la continuidad** del historial entre cambios de proveedor.

# %%
class Chatbot:
    """Orquesta la conversación con fallback en cascada entre proveedores."""

    DEFAULT_FALLBACK = (
        "Lo siento, ahora mismo no puedo procesar tu mensaje porque ninguno de los "
        "proveedores de IA está disponible. Por favor, inténtalo de nuevo más tarde."
    )

    def __init__(self, providers: list[BaseProvider],
                 system_prompt: str | None = None,
                 fallback_message: str | None = None):
        self.providers = providers
        self.conversation = Conversation(system_prompt=system_prompt)
        self.fallback_message = fallback_message or self.DEFAULT_FALLBACK

    def send(self, user_input: str) -> str:
        """Envía un mensaje del usuario y devuelve la respuesta del asistente."""
        self.conversation.add_user_message(user_input)

        for i, provider in enumerate(self.providers):
            try:
                print(f"\n[Asistente · {provider.name}]: ", end="", flush=True)
                respuesta = provider.generate(self.conversation)

                if not respuesta.strip():
                    raise RuntimeError("respuesta vacía del proveedor")

                # Éxito: guardamos en el historial y devolvemos
                self.conversation.add_assistant_message(respuesta)
                return respuesta

            except Exception as e:
                # Detección y notificación del fallo
                print(f"\n⚠️  {provider.name} no está disponible "
                      f"({type(e).__name__}: {e}).")
                if i + 1 < len(self.providers):
                    print(f"➡️  Cambiando a {self.providers[i + 1].name}…")
                continue

        # Todos los proveedores fallaron: respuesta preconfigurada
        print("\n❌ Ningún proveedor respondió. Usando respuesta preconfigurada.")
        print(f"[Asistente · fallback]: {self.fallback_message}")
        self.conversation.add_assistant_message(self.fallback_message)
        return self.fallback_message

# %% [markdown]
# ## 9. Interfaz CLI (`main.py`)
#
# Bucle conversacional interactivo. Escribe tus mensajes y pulsa Enter. Para terminar de forma limpia escribe **`/salir`** (también valen `/exit` o `/quit`, o `Ctrl-C`).
#
# En un notebook, la función `input()` abre un campo de texto sobre la celda en ejecución.

# %%
def run_cli():
    """Bucle principal de la interfaz de línea de comandos."""
    load_dotenv()

    # Configuración desde .env con valores por defecto cuando no están definidos
    anthropic_model = os.getenv("ANTHROPIC_MODEL", "claude-haiku-4-5-20251001")
    gemini_model = os.getenv("GEMINI_MODEL", "gemini-2.5-flash")
    system_prompt = os.getenv(
        "SYSTEM_PROMPT",
        "Eres un asistente útil y conciso. Respondes en español.",
    )
    fallback_message = os.getenv("FALLBACK_MESSAGE")

    # Dos pasos de Azure OpenAI (cada opción de cliente con su modelo)
    p1 = AzureOpenAIProvider(model="gpt-4o-mini", client_mode="openai")   # Opción 2
    p1.name = "Azure OpenAI · gpt-4o-mini (Op.2)"
    p2 = AzureOpenAIProvider(model="gpt-5.4-mini", client_mode="azure")   # Opción 1
    p2.name = "Azure OpenAI · gpt-5.4-mini (Op.1)"

    # Orden de prioridad del fallback
    providers = [
        p1,
        p2,
        AnthropicProvider(model=anthropic_model),
        GeminiProvider(model=gemini_model),
    ]

    bot = Chatbot(
        providers,
        system_prompt=system_prompt,
        fallback_message=fallback_message,
    )

    print("=" * 60)
    print("🤖 Chatbot con fallback (Azure Op.2 → Azure Op.1 → Anthropic → Google)")
    print("Escribe '/salir' para terminar.")
    print("=" * 60)

    while True:
        try:
            user_input = input("\n[Tú]: ").strip()
        except (EOFError, KeyboardInterrupt):
            print("\n👋 ¡Hasta luego!")
            break

        if not user_input:
            continue

        if user_input.lower() in ("/salir", "/exit", "/quit"):
            print("👋 ¡Hasta luego!")
            break

        bot.send(user_input)

# %% [markdown]
# ### ▶️ Iniciar la conversación
#
# Ejecuta la celda siguiente para lanzar el chatbot.

# %% [markdown]
# ### ▶️ Opción A — Conversar sin `input()` (recomendado en notebooks)
#
# Si el cuadro de texto de `input()` no te aparece o se queda colgado, usa este método: creas el bot **una sola vez** y luego le hablas pasando el mensaje como argumento de `bot.send(...)`. El historial se mantiene porque reutilizas el mismo objeto `bot`.
#
# **Importante:** antes de ejecutar estas celdas, ejecuta de arriba abajo las celdas de `Conversation`, los tres proveedores y `Chatbot` (o reinicia el kernel y ejecútalo todo).

# %%
# Crear el bot UNA sola vez (vuelve a ejecutar esta celda para reiniciar la conversación)
load_dotenv()

# Dos pasos de Azure OpenAI, cada uno con su cliente y su modelo
p1 = AzureOpenAIProvider(model="gpt-4o-mini", client_mode="openai")   # Opción 2
p1.name = "Azure OpenAI · gpt-4o-mini (Op.2)"
p2 = AzureOpenAIProvider(model="gpt-5.4-mini", client_mode="azure")   # Opción 1
p2.name = "Azure OpenAI · gpt-5.4-mini (Op.1)"

bot = Chatbot(
    [
        p1,
        p2,
        AnthropicProvider(model=os.getenv("ANTHROPIC_MODEL", "claude-haiku-4-5-20251001")),
        GeminiProvider(model=os.getenv("GEMINI_MODEL", "gemini-2.5-flash")),
    ],
    system_prompt=os.getenv("SYSTEM_PROMPT", "Eres un asistente útil y conciso. Respondes en español."),
)
print("Bot listo. Usa bot.send(\"tu mensaje\") en la siguiente celda.")
# Out:
# Bot listo. Usa bot.send("tu mensaje") en la siguiente celda.

# %%
# Cambia el texto y ejecuta esta celda tantas veces como quieras: el historial se conserva
bot.send("Hola, ¿cómo estás?")
# Out:
# [Asistente · Azure OpenAI · gpt-4o-mini (Op.2)]: ¡Hola! Estoy bien, gracias. ¿Y tú?
# '¡Hola! Estoy bien, gracias. ¿Y tú?'

# %%
# (Opcional) Ver el historial completo en memoria
for m in bot.conversation.messages:
    print(f"{m['role']}: {m['content']}")
# Out:
# user: Hola, ¿cómo estás?
# assistant: ¡Hola! Estoy bien, gracias. ¿Y tú?

# %% [markdown]
# ### ▶️ Opción B — CLI interactiva con `run_cli()`
#
# Usa el bucle con `input()` y salida con `/salir`. Funciona en una terminal real (`python main.py`). En notebooks, el cuadro de texto aparece debajo de la celda (Jupyter/Colab) o arriba en la paleta de comandos (VS Code).
#
# > Si esta celda se queda en `[*]` mucho tiempo, púlsa **stop (■)** o reinicia el kernel: significa que el `input()` está esperando o que un proveedor está agotando su timeout.

# %%
run_cli()
# Out:
# ============================================================
# 🤖 Chatbot con fallback (Azure Op.2 → Azure Op.1 → Anthropic → Google)
# Escribe '/salir' para terminar.
# ============================================================
#
# [Asistente · Azure OpenAI · gpt-4o-mini (Op.2)]: Soy un asistente virtual creado para ayudarte con información y responder tus preguntas. ¿En qué puedo ayudarte hoy?
#
# [Asistente · Azure OpenAI · gpt-4o-mini (Op.2)]: No soy directamente de Azure, pero puedo brindar información sobre sus servicios y funcionalidades. ¿Tienes alguna pregunta específica sobre Azure?
#
# [Asistente · Azure OpenAI · gpt-4o-mini (Op.2)]: Sí, algunos servicios de OpenAI pueden estar alojados en Azure. Esto permite ofrecer capacidades de procesamiento y escalabilidad. Si tienes preguntas sobre esta integración, estaré encantado de responderlas.
# 👋 ¡Hasta luego!

# %% [markdown]
# ## 10. (Opcional) Prueba rápida de la lógica de fallback sin claves reales
#
# Para comprobar la cascada y la respuesta preconfigurada sin gastar llamadas a las API, puedes usar proveedores simulados que fallan a propósito. Esta celda es solo demostrativa y **no forma parte de la solución entregable**.

# %%
class _FakeFail(BaseProvider):
    def __init__(self, name): self.name = name
    def generate(self, conversation):
        raise ConnectionError("simulación de fallo de proveedor")

class _FakeOK(BaseProvider):
    name = "Simulado OK"
    def generate(self, conversation):
        texto = "¡Hola! Soy una respuesta simulada que sí funciona."
        print(texto, end="", flush=True); print()
        return texto

# 1) Cascada hasta un proveedor que funciona
demo = Chatbot([_FakeFail("OpenAI"), _FakeFail("Anthropic"), _FakeOK()],
               system_prompt="demo")
demo.send("Hola, ¿me oyes?")
print("\nHistorial:", demo.conversation.messages)

print("\n" + "-" * 60)

# 2) Todos fallan -> respuesta preconfigurada
demo2 = Chatbot([_FakeFail("OpenAI"), _FakeFail("Anthropic"), _FakeFail("Google")],
                system_prompt="demo")
demo2.send("¿Y ahora?")
print("\nHistorial:", demo2.conversation.messages)
# Out:
# [Asistente · OpenAI]:
# ⚠️  OpenAI no está disponible (ConnectionError: simulación de fallo de proveedor).
# ➡️  Cambiando a Anthropic…
#
# [Asistente · Anthropic]:
# ⚠️  Anthropic no está disponible (ConnectionError: simulación de fallo de proveedor).
# ➡️  Cambiando a Simulado OK…
#
# [Asistente · Simulado OK]: ¡Hola! Soy una respuesta simulada que sí funciona.
#
# Historial: [{'role': 'user', 'content': 'Hola, ¿me oyes?'}, {'role': 'assistant', 'content': '¡Hola! Soy una respuesta simulada que sí funciona.'}]
#
# ------------------------------------------------------------
#
# [Asistente · OpenAI]:
# ⚠️  OpenAI no está disponible (ConnectionError: simulación de fallo de proveedor).
# ➡️  Cambiando a Anthropic…
#
# [Asistente · Anthropic]:
# ⚠️  Anthropic no está disponible (ConnectionError: simulación de fallo de proveedor).
# ➡️  Cambiando a Google…
#
# [Asistente · Google]:
# ⚠️  Google no está disponible (ConnectionError: simulación de fallo de proveedor).
#
# ❌ Ningún proveedor respondió. Usando respuesta preconfigurada.
# [Asistente · fallback]: Lo siento, ahora mismo no puedo procesar tu mensaje porque ninguno de los proveedores de IA está disponible. Por favor, inténtalo de nuevo más tarde.
#
# Historial: [{'role': 'user', 'content': '¿Y ahora?'}, {'role': 'assistant', 'content': 'Lo siento, ahora mismo no puedo procesar tu mensaje porque ninguno de los proveedores de IA está disponible. Por favor, inténtalo de nuevo más tarde.'}]

# %% [markdown]
# ## 11A. Probar los modelos en streaming (en vivo)
#
# Cada modelo escribe su respuesta **en directo**, una detrás de otra. La cabecera se imprime antes de cada `generate` para que sepas de qué modelo es cada bloque. Contras: líneas largas con scroll horizontal y, en VS Code, al copiar puede que solo te lleves el último tramo. Para copiar las 4 enteras, usa la 11B.

# %%
# 11A — Streaming puro: ver cada respuesta en vivo
load_dotenv()

MODELOS = ["gpt-4o", "gpt-4o-mini", "gpt-5.2-chat", "gpt-5.4-mini"]
CLIENTE = "openai"   # "openai" = Opción 2 | "azure" = Opción 1
PREGUNTA = "Explica en una sola frase qué es el aprendizaje por refuerzo."
SYS = "Eres un asistente conciso. Respondes en español."

for modelo in MODELOS:
    print(f"\n========== {modelo}  [{CLIENTE}] ==========")
    prov = AzureOpenAIProvider(model=modelo, client_mode=CLIENTE)
    conv = Conversation(system_prompt=SYS)
    conv.add_user_message(PREGUNTA)
    try:
        prov.generate(conv)          # imprime en streaming, no capturamos nada
    except Exception as e:
        print(f"❌ {type(e).__name__}: {e}")
# Out:
# ========== gpt-4o  [openai] ==========
# El aprendizaje por refuerzo es un método donde un agente aprende a tomar decisiones mediante la interacción con su entorno, recibiendo recompensas o castigos según sus acciones.
#
# ========== gpt-4o-mini  [openai] ==========
# El aprendizaje por refuerzo es un tipo de aprendizaje automático donde un agente toma decisiones en un entorno para maximizar una recompensa acumulada a través de la experiencia.
#
# ========== gpt-5.2-chat  [openai] ==========
# El aprendizaje por refuerzo es una técnica de aprendizaje automático en la que un agente aprende a tomar decisiones interactuando con un entorno y recibiendo recompensas o castigos según sus acciones.
#
# ========== gpt-5.4-mini  [openai] ==========
# El aprendizaje por refuerzo es un tipo de aprendizaje automático en el que un agente aprende a tomar decisiones probando acciones en un entorno y recibiendo recompensas o castigos para maximizar su beneficio a largo plazo.

# %% [markdown]
# ## 11B. Probar los modelos en streaming + resumen copiable
#
# Lo mejor de los dos: ves cada respuesta **en vivo** y, además, al terminar se reimprime un **resumen** con las 4 respuestas completas y las líneas ajustadas, para que puedas copiarlas enteras sin problemas de scroll ni truncado.
#
# Cambia `CLIENTE` a `"azure"` para la Opción 1, o `PREGUNTA` por lo que quieras.

# %%
# 11B — Híbrida: streaming en vivo + resumen copiable al final
import textwrap
load_dotenv()

MODELOS = ["gpt-4o", "gpt-4o-mini", "gpt-5.2-chat", "gpt-5.4-mini"]
CLIENTE = "openai"   # "openai" = Opción 2 | "azure" = Opción 1
PREGUNTA = "Explica en una sola frase qué es el aprendizaje por refuerzo."
SYS = "Eres un asistente conciso. Respondes en español."

respuestas = {}
for modelo in MODELOS:
    print(f"\n========== {modelo}  [{CLIENTE}] ==========")
    prov = AzureOpenAIProvider(model=modelo, client_mode=CLIENTE)
    conv = Conversation(system_prompt=SYS)
    conv.add_user_message(PREGUNTA)
    try:
        # generate() imprime en streaming Y devuelve el texto completo
        respuestas[modelo] = prov.generate(conv)
    except Exception as e:
        respuestas[modelo] = f"❌ {type(e).__name__}: {e}"

# Resumen final, ya completo y legible (copiable sin scroll horizontal)
print("\n\n===================== RESUMEN =====================")
for modelo, texto in respuestas.items():
    print(f"\n--- {modelo}  [{CLIENTE}] ---")
    print(textwrap.fill(texto.strip(), width=100))
# Out:
# ========== gpt-4o  [openai] ==========
# El aprendizaje por refuerzo es un paradigma de entrenamiento donde un agente aprende a tomar decisiones óptimas mediante prueba y error, recibiendo recompensas por acciones que maximicen su desempeño.
#
# ========== gpt-4o-mini  [openai] ==========
# El aprendizaje por refuerzo es un método de entrenamiento de agentes que aprenden a tomar decisiones mediante la interacción con el entorno y la optimización de recompensas.
#
# ========== gpt-5.2-chat  [openai] ==========
# El aprendizaje por refuerzo es un método de aprendizaje automático en el que un agente aprende a tomar decisiones interactuando con un entorno y recibiendo recompensas o castigos según sus acciones.
#
# ========== gpt-5.4-mini  [openai] ==========
# El aprendizaje por refuerzo es una técnica de inteligencia artificial en la que un agente aprende a tomar decisiones interactuando con un entorno y recibiendo recompensas o castigos según sus acciones.
#
#
# ===================== RESUMEN =====================
#
# --- gpt-4o  [openai] ---
# El aprendizaje por refuerzo es un paradigma de entrenamiento donde un agente aprende a tomar
# decisiones óptimas mediante prueba y error, recibiendo recompensas por acciones que maximicen su
# desempeño.
#
# --- gpt-4o-mini  [openai] ---
# El aprendizaje por refuerzo es un método de entrenamiento de agentes que aprenden a tomar decisiones
# mediante la interacción con el entorno y la optimización de recompensas.
#
# --- gpt-5.2-chat  [openai] ---
# El aprendizaje por refuerzo es un método de aprendizaje automático en el que un agente aprende a
# tomar decisiones interactuando con un entorno y recibiendo recompensas o castigos según sus
# acciones.
#
# --- gpt-5.4-mini  [openai] ---
# El aprendizaje por refuerzo es una técnica de inteligencia artificial en la que un agente aprende a
# tomar decisiones interactuando con un entorno y recibiendo recompensas o castigos según sus
# acciones.

# %%
# 1. Importar las librerías necesarias
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

# 2. Cargar los datos
data = pd.read_csv('dataset.csv')

# Eliminar espacios en los nombres de las columnas
data.columns = data.columns.str.strip()

# Verificar y eliminar filas con valores nulos en las columnas necesarias
# Puedes elegir eliminar todas las filas con NaN o rellenarlas (imputación)
data = data.dropna(subset=['BMI', 'GDP', 'Schooling', 'Adult Mortality', 'Income composition of resources', 'Life expectancy'])

# Verificar que no queden valores nulos
print(data.isnull().sum())

# 3. Dividir los datos en entrenamiento, validación y prueba
train_data, test_data = train_test_split(data, test_size=0.15, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)

# Definir las características numéricas y la variable objetivo
numeric_features = ['BMI', 'GDP', 'Schooling', 'Adult Mortality', 'Income composition of resources']
target = 'Life expectancy'

# 4. Normalización de las características (sin normalizar la variable objetivo)
scaler = StandardScaler()
train_data[numeric_features] = scaler.fit_transform(train_data[numeric_features])
val_data[numeric_features] = scaler.transform(val_data[numeric_features])
test_data[numeric_features] = scaler.transform(test_data[numeric_features])

# 5. Convertir los datos a tensores de PyTorch
X_train = torch.tensor(train_data[numeric_features].values, dtype=torch.float32)
y_train = torch.tensor(train_data[target].values, dtype=torch.float32).unsqueeze(1)
X_val = torch.tensor(val_data[numeric_features].values, dtype=torch.float32)
y_val = torch.tensor(val_data[target].values, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(test_data[numeric_features].values, dtype=torch.float32)
y_test = torch.tensor(test_data[target].values, dtype=torch.float32).unsqueeze(1)

# 6. Crear DataLoaders
train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=32, shuffle=False, num_workers=4)
test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=32, shuffle=False, num_workers=4)

# 7. Definir el modelo Feed-Forward en PyTorch
class FeedForwardNN(nn.Module):
    def __init__(self):
        super(FeedForwardNN, self).__init__()
        self.fc1 = nn.Linear(len(numeric_features), 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        return out

# Instanciar el modelo
model = FeedForwardNN()

# 8. Definir la función de coste (MSE) y el optimizador (Adam con `weight_decay`)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.01)

# 9. Entrenamiento del modelo
epochs = 100
train_losses = []
val_losses = []

for epoch in range(epochs):
    model.train()
    train_loss = 0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        predictions = model(X_batch)
        loss = criterion(predictions, y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_losses.append(train_loss / len(train_loader))
    
    # Validación en cada época
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            predictions = model(X_batch)
            loss = criterion(predictions, y_batch)
            val_loss += loss.item()
    val_losses.append(val_loss / len(val_loader))

    # Imprimir los resultados de la época
    print(f"Epoch {epoch+1}/{epochs}, Training Loss: {train_losses[-1]:.4f}, Validation Loss: {val_losses[-1]:.4f}")

# 10. Graficar la curva de pérdida
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title("Loss during training")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# 11. Evaluación del modelo en el conjunto de prueba
model.eval()
test_loss = 0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        predictions = model(X_batch)
        loss = criterion(predictions, y_batch)
        test_loss += loss.item()

print(f"Test Loss: {test_loss / len(test_loader):.4f}")
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                            147
# percentage expenditure               0
# Hepatitis B                        464
# Measles                              0
# BMI                                  0
# under-five deaths                    0
# Polio                                8
# Total expenditure                  149
# Diphtheria                           8
# HIV/AIDS                             0
# GDP                                  0
# Population                         220
# thinness  1-19 years                 0
# thinness 5-9 years                   0
# Income composition of resources      0
# Schooling                            0
# dtype: int64
# Epoch 1/100, Training Loss: 4474.2941, Validation Loss: 3789.7869
# Epoch 2/100, Training Loss: 2256.6166, Validation Loss: 1023.1505
# Epoch 3/100, Training Loss: 577.6359, Validation Loss: 414.6750
# Epoch 4/100, Training Loss: 295.5171, Validation Loss: 252.7515
# Epoch 5/100, Training Loss: 196.7157, Validation Loss: 174.1820
# Epoch 6/100, Training Loss: 141.8900, Validation Loss: 129.9388
# Epoch 7/100, Training Loss: 109.8774, Validation Loss: 104.1907
# Epoch 8/100, Training Loss: 86.4523, Validation Loss: 81.8913
# Epoch 9/100, Training Loss: 70.5853, Validation Loss: 67.6296
# Epoch 10/100, Training Loss: 58.5054, Validation Loss: 56.3415
# Epoch 11/100, Training Loss: 49.0645, Validation Loss: 49.0357
# Epoch 12/100, Training Loss: 41.5297, Validation Loss: 42.2009
# Epoch 13/100, Training Loss: 35.8081, Validation Loss: 38.2145
# Epoch 14/100, Training Loss: 31.0714, Validation Loss: 33.6209
# Epoch 15/100, Training Loss: 27.7787, Validation Loss: 30.3101
# Epoch 16/100, Training Loss: 25.0237, Validation Loss: 27.0782
# Epoch 17/100, Training Loss: 21.9424, Validation Loss: 25.5939
# Epoch 18/100, Training Loss: 19.6559, Validation Loss: 22.0209
# Epoch 19/100, Training Loss: 17.9485, Validation Loss: 20.7967
# Epoch 20/100, Training Loss: 16.0399, Validation Loss: 19.3328
# Epoch 21/100, Training Loss: 14.3821, Validation Loss: 16.8535
# Epoch 22/100, Training Loss: 13.4526, Validation Loss: 16.1122
# Epoch 23/100, Training Loss: 12.4201, Validation Loss: 14.6070
# Epoch 24/100, Training Loss: 11.5952, Validation Loss: 13.9696
# Epoch 25/100, Training Loss: 11.2555, Validation Loss: 13.3273
# Epoch 26/100, Training Loss: 11.0822, Validation Loss: 13.1763
# Epoch 27/100, Training Loss: 10.6782, Validation Loss: 13.5522
# Epoch 28/100, Training Loss: 10.4850, Validation Loss: 13.2821
# Epoch 29/100, Training Loss: 10.3145, Validation Loss: 12.8132
# Epoch 30/100, Training Loss: 10.0113, Validation Loss: 12.2317
# Epoch 31/100, Training Loss: 10.0635, Validation Loss: 12.2882
# Epoch 32/100, Training Loss: 9.7614, Validation Loss: 12.6524
# Epoch 33/100, Training Loss: 9.5128, Validation Loss: 12.9356
# Epoch 34/100, Training Loss: 9.4170, Validation Loss: 11.9472
# Epoch 35/100, Training Loss: 9.3197, Validation Loss: 11.8510
# Epoch 36/100, Training Loss: 9.1375, Validation Loss: 12.0809
# Epoch 37/100, Training Loss: 9.0491, Validation Loss: 11.8911
# Epoch 38/100, Training Loss: 9.1242, Validation Loss: 11.5273
# Epoch 39/100, Training Loss: 8.8251, Validation Loss: 11.8388
# Epoch 40/100, Training Loss: 8.7857, Validation Loss: 12.7525
# Epoch 41/100, Training Loss: 8.8590, Validation Loss: 11.7156
# Epoch 42/100, Training Loss: 8.7170, Validation Loss: 11.4576
# Epoch 43/100, Training Loss: 8.3751, Validation Loss: 12.5273
# Epoch 44/100, Training Loss: 8.5188, Validation Loss: 12.0091
# Epoch 45/100, Training Loss: 8.2218, Validation Loss: 11.2868
# Epoch 46/100, Training Loss: 8.1908, Validation Loss: 11.5205
# Epoch 47/100, Training Loss: 8.4949, Validation Loss: 11.4318
# Epoch 48/100, Training Loss: 8.3526, Validation Loss: 11.8357
# Epoch 49/100, Training Loss: 8.2613, Validation Loss: 11.4319
# Epoch 50/100, Training Loss: 8.1663, Validation Loss: 11.2286
# Epoch 51/100, Training Loss: 7.9973, Validation Loss: 11.0076
# Epoch 52/100, Training Loss: 8.0115, Validation Loss: 10.5213
# Epoch 53/100, Training Loss: 7.9785, Validation Loss: 11.8157
# Epoch 54/100, Training Loss: 7.8985, Validation Loss: 10.9995
# Epoch 55/100, Training Loss: 7.9604, Validation Loss: 11.0154
# Epoch 56/100, Training Loss: 7.9629, Validation Loss: 11.4418
# Epoch 57/100, Training Loss: 7.9498, Validation Loss: 11.5706
# Epoch 58/100, Training Loss: 7.8042, Validation Loss: 10.5251
# Epoch 59/100, Training Loss: 7.8103, Validation Loss: 11.0610
# Epoch 60/100, Training Loss: 7.8410, Validation Loss: 11.8995
# Epoch 61/100, Training Loss: 7.9502, Validation Loss: 10.9142
# Epoch 62/100, Training Loss: 7.7071, Validation Loss: 10.4724
# Epoch 63/100, Training Loss: 7.9121, Validation Loss: 10.9392
# Epoch 64/100, Training Loss: 7.9146, Validation Loss: 11.2774
# Epoch 65/100, Training Loss: 7.9629, Validation Loss: 11.6192
# Epoch 66/100, Training Loss: 7.5230, Validation Loss: 11.5905
# Epoch 67/100, Training Loss: 7.8750, Validation Loss: 11.5049
# Epoch 68/100, Training Loss: 7.7389, Validation Loss: 11.1910
# Epoch 69/100, Training Loss: 7.4426, Validation Loss: 11.5894
# Epoch 70/100, Training Loss: 7.5460, Validation Loss: 10.3354
# Epoch 71/100, Training Loss: 7.6202, Validation Loss: 10.5136
# Epoch 72/100, Training Loss: 7.3875, Validation Loss: 10.8003
# Epoch 73/100, Training Loss: 7.3921, Validation Loss: 10.7501
# Epoch 74/100, Training Loss: 7.3912, Validation Loss: 11.0550
# Epoch 75/100, Training Loss: 7.2046, Validation Loss: 10.3116
# Epoch 76/100, Training Loss: 7.3575, Validation Loss: 10.7708
# Epoch 77/100, Training Loss: 7.3121, Validation Loss: 10.6183
# Epoch 78/100, Training Loss: 7.4500, Validation Loss: 10.7252
# Epoch 79/100, Training Loss: 7.3075, Validation Loss: 10.8160
# Epoch 80/100, Training Loss: 7.2619, Validation Loss: 10.4205
# Epoch 81/100, Training Loss: 7.2234, Validation Loss: 10.8942
# Epoch 82/100, Training Loss: 7.3549, Validation Loss: 10.4520
# Epoch 83/100, Training Loss: 7.2068, Validation Loss: 10.3061
# Epoch 84/100, Training Loss: 7.2401, Validation Loss: 11.0496
# Epoch 85/100, Training Loss: 7.1377, Validation Loss: 10.3548
# Epoch 86/100, Training Loss: 7.1382, Validation Loss: 10.9439
# Epoch 87/100, Training Loss: 7.2877, Validation Loss: 10.3159
# Epoch 88/100, Training Loss: 7.2422, Validation Loss: 11.6848
# Epoch 89/100, Training Loss: 7.0850, Validation Loss: 12.0872
# Epoch 90/100, Training Loss: 7.4114, Validation Loss: 10.4973
# Epoch 91/100, Training Loss: 7.1118, Validation Loss: 10.3158
# Epoch 92/100, Training Loss: 7.1245, Validation Loss: 10.3035
# Epoch 93/100, Training Loss: 7.0919, Validation Loss: 10.4524
# Epoch 94/100, Training Loss: 7.2519, Validation Loss: 10.6001
# Epoch 95/100, Training Loss: 7.0157, Validation Loss: 10.7453
# Epoch 96/100, Training Loss: 6.9501, Validation Loss: 10.7213
# Epoch 97/100, Training Loss: 6.9758, Validation Loss: 11.1370
# Epoch 98/100, Training Loss: 7.6119, Validation Loss: 11.6495
# Epoch 99/100, Training Loss: 7.1122, Validation Loss: 10.2076
# Epoch 100/100, Training Loss: 7.0886, Validation Loss: 10.4021
# Test Loss: 9.1113
